# %%
import pandas as pd

# %%
df1 = pd.read_csv("data.csv")
df2 = pd.read_csv("data2.csv")
df2.rename(columns={column: column + "2" for column in df2.columns}, inplace=True)
df = pd.concat([df1, df2], axis=1)

# %%
df['Material'].fillna("None", inplace=True)
df['Material2'].fillna("None", inplace=True)

# %%
df.loc[(df['Time'] != df['Time2']) | (df['Resource'] != df['Resource2']) | (df['Material'] != df['Material2'])]
# Out:
#        Unnamed: 0          Time Resource State     Activity  \
# 65             65     76.565978      TR1   TP1  start state
# 66             66     77.857229      TR2   TP1    end state
# 68             68     78.549312      TR1   TP1    end state
# 69             69     78.549312      TR1   TP1  start state
# 70             70     79.365978      TR1   TP1    end state
# ...           ...           ...      ...   ...          ...
# 67040       67040  39998.952130      TR1   TP1  start state
# 67041       67041  39999.231598      TR2   TP1    end state
# 67042       67042  39999.231598      TR2   TP1  start state
# 67043       67043  39999.435464      TR1   TP1    end state
# 67044       67044  39999.435464      TR1   TP1  start state
#
#                          Material  Expected End Time Target location  \
# 65        Material_1 instance N.1          78.549312              R3
# 66        Material_3 instance N.4          77.857229              R4
# 68        Material_1 instance N.1          78.549312              R3
# 69        Material_1 instance N.1          79.365978              R1
# 70        Material_1 instance N.1          79.365978              R1
# ...                           ...                ...             ...
# 67040  Material_2 instance N.2571       39999.435464              R3
# 67041  Material_1 instance N.2573       39999.231598              R3
# 67042  Material_1 instance N.2584       40001.381598             SK1
# 67043  Material_2 instance N.2571       39999.435464              R3
# 67044  Material_3 instance N.2539       40001.418797             SK3
#
#        Unnamed: 02      Time2 Resource2 State2    Activity2  \
# 65            65.0  77.857229       TR2    TP1    end state
# 66            66.0  77.857229       TR2    TP1  start state
# 68            68.0  78.340563       TR2    TP1    end state
# 69            69.0  78.340563       TR2    TP1  start state
# 70            70.0  78.823896       TR2    TP1    end state
# ...            ...        ...       ...    ...          ...
# 67040          NaN        NaN       NaN    NaN          NaN
# 67041          NaN        NaN       NaN    NaN          NaN
# 67042          NaN        NaN       NaN    NaN          NaN
# 67043          NaN        NaN       NaN    NaN          NaN
# 67044          NaN        NaN       NaN    NaN          NaN
#
#                      Material2  Expected End Time2 Target location2
# 65     Material_3 instance N.4           77.857229               R4
# 66     Material_1 instance N.1           78.340563               R3
# 68     Material_1 instance N.1           78.340563               R3
# 69     Material_1 instance N.1           78.823896               R2
# 70     Material_1 instance N.1           78.823896               R2
# ...                        ...                 ...              ...
# 67040                     None                 NaN              NaN
# 67041                     None                 NaN              NaN
# 67042                     None                 NaN              NaN
# 67043                     None                 NaN              NaN
# 67044                     None                 NaN              NaN
#
# [66974 rows x 16 columns]
