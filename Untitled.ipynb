# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0       Time Resource             State     Activtiy  \
# 0            0  14.532972       R3  Breakdownstate_2  start state
# 1            1  34.609251       R1                P1  start state
# 2            2  44.532972       R3  Breakdownstate_2    end state
# 3            3  47.596494       R3  Breakdownstate_2  start state
# 4            4  51.789581      TR1  Breakdownstate_1  start state
# 5            5  51.965732       R1                P1    end state
# 6            6  77.596494       R3  Breakdownstate_2    end state
# 7            8  81.789581      TR1               TP1  start state
# 8            7  81.789581      TR1  Breakdownstate_1    end state
# 9            9  81.845137      TR1               TP1    end state
# 10          10  81.845137      TR1               TP1  start state
# 11          11  81.900692      TR1               TP1    end state
# 12          12  81.900692       R2                P2  start state
# ...

# %%
df.loc[df['Material'] == "Material_2 instance N.26"]
# Out:
#      Unnamed: 0        Time Resource State     Activtiy  Expected End Time  \
# 393         393  842.699425       R3    P1  start state         855.351281
# 395         395  855.351281       R3    P1    end state         855.351281
# 396         396  855.351281      TR1   TP1    end state         763.347620
# 400         400  884.814047       R3    P3  start state         891.573719
# 402         402  891.573719       R3    P3    end state         891.573719
# 408         408  917.750385      TR1   TP1  start state         917.861496
# 411         413  917.861496       R1    P2  start state         932.861496
# 412         411  917.861496      TR1   TP1    end state         917.861496
# 423         423  932.861496       R1    P2    end state         932.861496
# 424         424  932.861496      TR1   TP1  start state         932.917052
# 425         425  932.917052      TR1   TP1    end state         932.917052
# ...

# %%
df.loc[df['Resource'] == "R3"][60::].head(50)
# Out:
#      Unnamed: 0         Time Resource             State         Activtiy  \
# 336         336   697.201371       R3                P1      start state
# 349         349   709.478002       R3                P1        end state
# 362         362   745.033366       R3  Breakdownstate_1      start state
# 377         377   775.033366       R3  Breakdownstate_1        end state
# 378         378   775.033366       R3                P1      start state
# 379         379   775.033366       R3  Breakdownstate_2      start state
# 380         380   775.033366       R3                P1  start interrupt
# 383         384   805.033366       R3                P1    end interrupt
# 384         385   805.033366       R3                P1      start state
# 385         383   805.033366       R3  Breakdownstate_2        end state
# 386         386   810.479004       R3  Breakdownstate_1      start state
# 387         387   810.479004       R3                P1  start interrupt
# ...
