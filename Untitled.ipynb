# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
# Out:
# C:\Users\Sebas\AppData\Local\Temp\ipykernel_6416\1507164070.py:1: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0       Time Resource             State     Activtiy  \
# 0            0  14.532972       R3  Breakdownstate_2  start state
# 1            1  34.609251       R1                P1  start state
# 2            2  44.532972       R3  Breakdownstate_2    end state
# 3            3  47.596494       R3  Breakdownstate_2  start state
# 4            4  51.789581      TR1  Breakdownstate_1  start state
# 5            5  51.965732       R1                P1    end state
# 6            6  77.596494       R3  Breakdownstate_2    end state
# 7            7  81.789581      TR1  Breakdownstate_1    end state
# 8            8  81.789581      TR1               TP1  start state
# 9            9  81.845137      TR1               TP1    end state
# 10          10  81.845137      TR1               TP1  start state
# 11          11  81.900692      TR1               TP1    end state
# 12          12  81.900692       R2                P2  start state
# ...

# %%
df.loc[df['Material'] == "Material_2 instance N.2"]
# Out:
#     Unnamed: 0        Time Resource State     Activtiy  Expected End Time  \
# 14          14   93.487928       R1    P1  start state          97.266674
# 20          20   97.266674      TR1   TP1  start state          97.377785
# 21          21   97.377785      TR1   TP1    end state          97.377785
# 22          22   97.377785       R3    P3  start state         106.423757
# 27          27  106.423757       R3    P3    end state         106.423757
# 28          28  106.423757      TR1   TP1  start state         106.534869
# 29          29  106.534869      TR1   TP1    end state         106.534869
# 30          30  106.534869      TR1   TP1  start state         106.590424
# 31          31  106.590424      TR1   TP1    end state         106.590424
# 32          32  106.590424       R2    P2  start state         121.590424
# 40          40  121.590424       R2    P2    end state         121.590424
# 41          41  121.590424      TR1   TP1  start state         121.645980
# ...
