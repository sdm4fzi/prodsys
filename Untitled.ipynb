# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0       Time Resource             State     Activity  \
# 0            0  14.532972       R3  Breakdownstate_2  start state
# 1            1  22.523481       R1                P1  start state
# 2            2  40.622365       R1                P1    end state
# 3            3  40.622365      TR1               TP1  start state
# 4            4  40.883477      TR1               TP1    end state
# 5            5  40.883477      TR1               TP1  start state
# 6            6  41.144588      TR1               TP1    end state
# 7            7  41.144588       R2                P2  start state
# 8            8  44.532972       R3  Breakdownstate_2    end state
# 9            9  47.596494       R3  Breakdownstate_2  start state
# 10          10  51.789581      TR1  Breakdownstate_1  start state
# 11          11  54.760325      TR2  Breakdownstate_1  start state
# 12          12  56.144588       R2                P2    end state
# ...

# %%
df.loc[df['Material'] == "Material_2 instance N.26"]
# Out:
#      Unnamed: 0        Time Resource State         Activity  \
# 376         376  528.492451       R1    P1      start state
# 389         388  538.947700       R1    P1  start interrupt
# 399         399  568.947700       R1    P1    end interrupt
# 401         400  568.947700       R1    P1      start state
# 403         403  569.882894       R1    P1        end state
# 404         404  569.882894      TR2   TP1      start state
# 405         405  570.144005      TR2   TP1        end state
# 407         407  580.750808       R2    P3      start state
# 415         415  600.172237       R2    P3        end state
# 416         416  600.172237      TR1   TP1      start state
# 417         417  600.322237      TR1   TP1        end state
# 418         418  600.322237       R2    P2      start state
# 428         428  615.322237       R2    P2        end state
# 430         430  615.322237      TR2   TP1      start state
# 431         431  615.583348      TR2   TP1        end state
# ...

# %%
df.loc[df['Resource'] == "R3"][180::].head(50)
# Out:
#       Unnamed: 0         Time Resource             State         Activity  \
# 1110        1110  1388.227519       R3  Breakdownstate_1        end state
# 1111        1111  1388.227519       R3                P1    end interrupt
# 1112        1112  1388.227519       R3                P1      start state
# 1118        1118  1392.535686       R3                P1        end state
# 1119        1119  1392.535686       R3                P1      start state
# 1120        1120  1392.535686       R3                P3      start state
# 1121        1123  1395.001687       R3  Breakdownstate_1      start state
# 1122        1121  1395.001687       R3                P1  start interrupt
# 1123        1122  1395.001687       R3                P3  start interrupt
# 1146        1146  1425.001687       R3  Breakdownstate_1        end state
# 1147        1147  1425.001687       R3                P1    end interrupt
# 1148        1149  1425.001687       R3                P3    end interrupt
# ...

# %%
print(df['Activity'].unique())
# Out:
# ['start state' 'end state' 'start interrupt' 'end interrupt']
