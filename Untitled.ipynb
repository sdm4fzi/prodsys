# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0       Time Resource             State     Activtiy  \
# 0            0  14.532972       R3  Breakdownstate_2  start state
# 1            1  34.609251       R1                P1  start state
# 2            2  44.532972       R3  Breakdownstate_2    end state
# 3            3  47.596494       R3  Breakdownstate_2  start state
# 4            4  51.789581      TR1  Breakdownstate_1  start state
# 5            5  51.965732       R1                P1    end state
# 6            6  77.596494       R3  Breakdownstate_2    end state
# 7            7  81.789581      TR1  Breakdownstate_1    end state
# 8            8  81.789581      TR1               TP1  start state
# 9            9  82.050692      TR1               TP1    end state
# 10          10  82.050692      TR1               TP1  start state
# 11          11  82.311803      TR1               TP1    end state
# 12          12  82.311803       R2                P2  start state
# ...

# %%
df.loc[df['Material'] == "Material_2 instance N.26"]
# Out:
#      Unnamed: 0         Time Resource State         Activtiy  \
# 423         424   845.518710       R3    P1      start state
# 426         425   854.814047       R3    P1  start interrupt
# 429         429   884.814047       R3    P1    end interrupt
# 430         430   884.814047       R3    P1      start state
# 432         432   887.795341       R3    P1        end state
# 438         438   917.750385      TR1   TP1      start state
# 441         441   917.900385      TR1   TP1        end state
# 451         454   953.517103       R3    P3      start state
# 472         472   978.543524       R3    P3        end state
# 473         473   978.543524      TR1   TP1      start state
# 474         474   978.804635      TR1   TP1        end state
# 475         475   978.804635      TR1   TP1      start state
# 476         476   979.065746      TR1   TP1        end state
# 487         487   998.778214       R2    P2      start state
# ...

# %%
df.loc[df['Resource'] == "TR1"][180::].head(50)
# Out:
#      Unnamed: 0        Time Resource             State     Activtiy  \
# 346         346  658.336036      TR1               TP1  start state
# 348         348  658.486036      TR1               TP1    end state
# 351         351  667.145816      TR1  Breakdownstate_1  start state
# 359         359  697.145816      TR1  Breakdownstate_1    end state
# 360         360  697.145816      TR1               TP1  start state
# 361         361  697.406927      TR1               TP1    end state
# 362         362  697.406927      TR1               TP1  start state
# 363         363  697.556927      TR1               TP1    end state
# 364         364  697.556927      TR1               TP1  start state
# 366         367  697.818038      TR1               TP1  start state
# 367         366  697.818038      TR1               TP1    end state
# 369         369  698.079149      TR1               TP1  start state
# 370         368  698.079149      TR1               TP1    end state
# ...
